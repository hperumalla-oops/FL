# %%
import sys
print(sys.executable)
# Out:
# C:\Users\hperu\anaconda3\envs\py310\python.exe

# %%
# !{sys.executable} -m pip install "flwr[simulation]"
import flwr
print(flwr.__version__)
# Out:
# Collecting flwr[simulation]
#   Using cached flwr-1.18.0-py3-none-any.whl.metadata (15 kB)
# Collecting cryptography<45.0.0,>=44.0.1 (from flwr[simulation])
#   Using cached cryptography-44.0.3-cp39-abi3-win_amd64.whl.metadata (5.7 kB)
# Requirement already satisfied: grpcio!=1.65.0,<2.0.0,>=1.62.3 in c:\users\hperu\anaconda3\envs\py310\lib\site-packages (from flwr[simulation]) (1.71.0)
# Collecting iterators<0.0.3,>=0.0.2 (from flwr[simulation])
#   Using cached iterators-0.0.2-py3-none-any.whl.metadata (2.5 kB)
# Collecting numpy<3.0.0,>=1.26.0 (from flwr[simulation])
#   Downloading numpy-2.2.5-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Collecting pathspec<0.13.0,>=0.12.1 (from flwr[simulation])
#   Using cached pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Collecting protobuf<5.0.0,>=4.21.6 (from flwr[simulation])
#   Using cached protobuf-4.25.7-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Collecting pycryptodome<4.0.0,>=3.18.0 (from flwr[simulation])
#   Using cached pycryptodome-3.22.0-cp37-abi3-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.2 in c:\users\hperu\anaconda3\envs\py310\lib\site-packages (from flwr[simulation]) (6.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in c:\users\hperu\anaconda3\envs\py310\lib\site-packages (from flwr[simulation]) (2.32.3)
# Collecting rich<14.0.0,>=13.5.0 (from flwr[simulation])
#   Using cached rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: tomli<3.0.0,>=2.0.1 in c:\users\hperu\anaconda3\envs\py310\lib\site-packages (from flwr[simulation]) (2.2.1)
# Collecting tomli-w<2.0.0,>=1.0.0 (from flwr[simulation])
#   Using cached tomli_w-1.2.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting typer<0.13.0,>=0.12.5 (from flwr[simulation])
#   Using cached typer-0.12.5-py3-none-any.whl.metadata (15 kB)
# Collecting ray==2.31.0 (from flwr[simulation])
#   Downloading ray-2.31.0-cp310-cp310-win_amd64.whl.metadata (13 kB)
# Collecting click>=7.0 (from ray==2.31.0->flwr[simulation])
#   Downloading click-8.2.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting filelock (from ray==2.31.0->flwr[simulation])
#   Using cached filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: jsonschema in c:\users\hperu\anaconda3\envs\py310\lib\site-packages (from ray==2.31.0->flwr[simulation]) (4.23.0)
# Collecting msgpack<2.0.0,>=1.0.0 (from ray==2.31.0->flwr[simulation])
#   Downloading msgpack-1.1.0-cp310-cp310-win_amd64.whl.metadata (8.6 kB)
# Requirement already satisfied: packaging in c:\users\hperu\anaconda3\envs\py310\lib\site-packages (from ray==2.31.0->flwr[simulation]) (24.2)
# Requirement already satisfied: aiosignal in c:\users\hperu\anaconda3\envs\py310\lib\site-packages (from ray==2.31.0->flwr[simulation]) (1.3.2)
# Requirement already satisfied: frozenlist in c:\users\hperu\anaconda3\envs\py310\lib\site-packages (from ray==2.31.0->flwr[simulation]) (1.6.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\hperu\anaconda3\envs\py310\lib\site-packages (from cryptography<45.0.0,>=44.0.1->flwr[simulation]) (1.17.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hperu\anaconda3\envs\py310\lib\site-packages (from requests<3.0.0,>=2.31.0->flwr[simulation]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hperu\anaconda3\envs\py310\lib\site-packages (from requests<3.0.0,>=2.31.0->flwr[simulation]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hperu\anaconda3\envs\py310\lib\site-packages (from requests<3.0.0,>=2.31.0->flwr[simulation]) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hperu\anaconda3\envs\py310\lib\site-packages (from requests<3.0.0,>=2.31.0->flwr[simulation]) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\hperu\anaconda3\envs\py310\lib\site-packages (from rich<14.0.0,>=13.5.0->flwr[simulation]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hperu\anaconda3\envs\py310\lib\site-packages (from rich<14.0.0,>=13.5.0->flwr[simulation]) (2.19.1)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in c:\users\hperu\anaconda3\envs\py310\lib\site-packages (from rich<14.0.0,>=13.5.0->flwr[simulation]) (4.13.2)
# Collecting shellingham>=1.3.0 (from typer<0.13.0,>=0.12.5->flwr[simulation])
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: pycparser in c:\users\hperu\anaconda3\envs\py310\lib\site-packages (from cffi>=1.12->cryptography<45.0.0,>=44.0.1->flwr[simulation]) (2.22)
# Requirement already satisfied: colorama in c:\users\hperu\anaconda3\envs\py310\lib\site-packages (from click>=7.0->ray==2.31.0->flwr[simulation]) (0.4.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hperu\anaconda3\envs\py310\lib\site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.5.0->flwr[simulation]) (0.1.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\hperu\anaconda3\envs\py310\lib\site-packages (from jsonschema->ray==2.31.0->flwr[simulation]) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\hperu\anaconda3\envs\py310\lib\site-packages (from jsonschema->ray==2.31.0->flwr[simulation]) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\hperu\anaconda3\envs\py310\lib\site-packages (from jsonschema->ray==2.31.0->flwr[simulation]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\hperu\anaconda3\envs\py310\lib\site-packages (from jsonschema->ray==2.31.0->flwr[simulation]) (0.24.0)
# Downloading ray-2.31.0-cp310-cp310-win_amd64.whl (26.1 MB)
#    ---------------------------------------- 0.0/26.1 MB ? eta -:--:--
#    - -------------------------------------- 1.0/26.1 MB 25.4 MB/s eta 0:00:01
#    --- ------------------------------------ 2.1/26.1 MB 5.3 MB/s eta 0:00:05
#    ---- ----------------------------------- 3.1/26.1 MB 5.0 MB/s eta 0:00:05
#    ---- ----------------------------------- 3.1/26.1 MB 5.0 MB/s eta 0:00:05
#    ------ --------------------------------- 4.2/26.1 MB 4.3 MB/s eta 0:00:06
#    -------- ------------------------------- 5.2/26.1 MB 4.1 MB/s eta 0:00:06
#    ---------- ----------------------------- 6.6/26.1 MB 4.3 MB/s eta 0:00:05
#    ---------- ----------------------------- 6.6/26.1 MB 4.3 MB/s eta 0:00:05
#    ------------ --------------------------- 8.4/26.1 MB 4.5 MB/s eta 0:00:04
#    ------------- -------------------------- 8.9/26.1 MB 4.3 MB/s eta 0:00:05
#    ---------------- ----------------------- 10.5/26.1 MB 4.4 MB/s eta 0:00:04
#    ---------------- ----------------------- 10.5/26.1 MB 4.4 MB/s eta 0:00:04
#    ----------------- ---------------------- 11.5/26.1 MB 4.3 MB/s eta 0:00:04
#    ------------------- -------------------- 12.6/26.1 MB 4.3 MB/s eta 0:00:04
#    -------------------- ------------------- 13.6/26.1 MB 4.3 MB/s eta 0:00:03
#    -------------------- ------------------- 13.6/26.1 MB 4.3 MB/s eta 0:00:03
#    -------------------- ------------------- 13.6/26.1 MB 4.3 MB/s eta 0:00:03
#    -------------------- ------------------- 13.6/26.1 MB 4.3 MB/s eta 0:00:03
#    -------------------- ------------------- 13.6/26.1 MB 4.3 MB/s eta 0:00:03
#    ---------------------- ----------------- 14.7/26.1 MB 3.5 MB/s eta 0:00:04
#    ------------------------ --------------- 15.7/26.1 MB 3.5 MB/s eta 0:00:03
#    -------------------------- ------------- 17.6/26.1 MB 3.7 MB/s eta 0:00:03
#    --------------------------- ------------ 17.8/26.1 MB 3.8 MB/s eta 0:00:03
#    --------------------------- ------------ 18.1/26.1 MB 3.6 MB/s eta 0:00:03
#    ---------------------------- ----------- 18.9/26.1 MB 3.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 18.9/26.1 MB 3.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 18.9/26.1 MB 3.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 18.9/26.1 MB 3.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 18.9/26.1 MB 3.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 18.9/26.1 MB 3.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 18.9/26.1 MB 3.5 MB/s eta 0:00:03
#    ---------------------------- ----------- 18.9/26.1 MB 3.5 MB/s eta 0:00:03
#    ------------------------------ --------- 19.9/26.1 MB 2.8 MB/s eta 0:00:03
#    ------------------------------ --------- 19.9/26.1 MB 2.8 MB/s eta 0:00:03
#    ------------------------------- -------- 20.4/26.1 MB 2.7 MB/s eta 0:00:03
#    -------------------------------- ------- 21.2/26.1 MB 2.7 MB/s eta 0:00:02
#    --------------------------------- ------ 22.0/26.1 MB 2.8 MB/s eta 0:00:02
#    --------------------------------- ------ 22.0/26.1 MB 2.8 MB/s eta 0:00:02
#    --------------------------------- ------ 22.0/26.1 MB 2.8 MB/s eta 0:00:02
#    --------------------------------- ------ 22.0/26.1 MB 2.8 MB/s eta 0:00:02
#    --------------------------------- ------ 22.0/26.1 MB 2.8 MB/s eta 0:00:02
#    ----------------------------------- ---- 23.1/26.1 MB 2.6 MB/s eta 0:00:02
#    ------------------------------------ --- 24.1/26.1 MB 2.6 MB/s eta 0:00:01
#    -------------------------------------- - 25.2/26.1 MB 2.7 MB/s eta 0:00:01
#    -------------------------------------- - 25.2/26.1 MB 2.7 MB/s eta 0:00:01
#    -------------------------------------- - 25.2/26.1 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------  25.7/26.1 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 26.1/26.1 MB 2.6 MB/s eta 0:00:00
# Using cached cryptography-44.0.3-cp39-abi3-win_amd64.whl (3.2 MB)
# Using cached iterators-0.0.2-py3-none-any.whl (3.9 kB)
# Downloading numpy-2.2.5-cp310-cp310-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    -------- ------------------------------- 2.9/12.9 MB 15.2 MB/s eta 0:00:01
#    -------- ------------------------------- 2.9/12.9 MB 15.2 MB/s eta 0:00:01
#    -------- ------------------------------- 2.9/12.9 MB 15.2 MB/s eta 0:00:01
#    -------- ------------------------------- 2.9/12.9 MB 15.2 MB/s eta 0:00:01
#    ---------- ----------------------------- 3.4/12.9 MB 3.1 MB/s eta 0:00:04
#    ----------------- ---------------------- 5.5/12.9 MB 4.2 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.5/12.9 MB 4.2 MB/s eta 0:00:02
#    ------------------- -------------------- 6.3/12.9 MB 3.6 MB/s eta 0:00:02
#    ------------------------ --------------- 7.9/12.9 MB 4.1 MB/s eta 0:00:02
#    ------------------------ --------------- 7.9/12.9 MB 4.1 MB/s eta 0:00:02
#    --------------------------- ------------ 8.9/12.9 MB 3.8 MB/s eta 0:00:02
#    ------------------------------- -------- 10.2/12.9 MB 4.0 MB/s eta 0:00:01
#    -------------------------------- ------- 10.5/12.9 MB 4.1 MB/s eta 0:00:01
#    -------------------------------- ------- 10.5/12.9 MB 4.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.5/12.9 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  12.8/12.9 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 3.7 MB/s eta 0:00:00
# Using cached pathspec-0.12.1-py3-none-any.whl (31 kB)
# Using cached protobuf-4.25.7-cp310-abi3-win_amd64.whl (413 kB)
# Using cached pycryptodome-3.22.0-cp37-abi3-win_amd64.whl (1.8 MB)
# Using cached rich-13.9.4-py3-none-any.whl (242 kB)
# Using cached tomli_w-1.2.0-py3-none-any.whl (6.7 kB)
# Using cached typer-0.12.5-py3-none-any.whl (47 kB)
# Using cached flwr-1.18.0-py3-none-any.whl (540 kB)
# Downloading click-8.2.0-py3-none-any.whl (102 kB)
# Downloading msgpack-1.1.0-cp310-cp310-win_amd64.whl (74 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached filelock-3.18.0-py3-none-any.whl (16 kB)
# Installing collected packages: tomli-w, shellingham, pycryptodome, protobuf, pathspec, numpy, msgpack, iterators, filelock, click, rich, cryptography, typer, ray, flwr
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.4
#     Uninstalling numpy-1.24.4:
#       Successfully uninstalled numpy-1.24.4
# Successfully installed click-8.2.0 cryptography-44.0.3 filelock-3.18.0 flwr-1.18.0 iterators-0.0.2 msgpack-1.1.0 numpy-2.2.5 pathspec-0.12.1 protobuf-4.25.7 pycryptodome-3.22.0 ray-2.31.0 rich-13.9.4 shellingham-1.5.4 tomli-w-1.2.0 typer-0.12.5
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\hperu\anaconda3\envs\py310\Lib\site-packages\google\~rotobuf'.
#   You can safely remove it manually.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'C:\Users\hperu\anaconda3\envs\py310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\hperu\anaconda3\envs\py310\Lib\site-packages\~umpy'.
#   You can safely remove it manually.
#   WARNING: The script typer.exe is installed in 'C:\Users\hperu\anaconda3\envs\py310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts ray.exe, rllib.exe, serve.exe and tune.exe are installed in 'C:\Users\hperu\anaconda3\envs\py310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts flower-simulation.exe, flower-superlink.exe, flower-supernode.exe, flwr-clientapp.exe, flwr-serverapp.exe, flwr-simulation.exe and flwr.exe are installed in 'C:\Users\hperu\anaconda3\envs\py310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorboard 2.10.1 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.25.7 which is incompatible.
# tensorflow 2.10.1 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.25.7 which is incompatible.
# -------------------------------------------------
# TypeError       Traceback (most recent call last)
# Cell In[27], line 2
#       1 get_ipython().system('{sys.executable} -m pip install "flwr[simulation]"')
# ----> 2 import flwr
#       3 print(flwr.__version__)
#
# File ~\anaconda3\envs\py310\lib\site-packages\flwr\__init__.py:20
#      15 """Flower main package."""
#      18 from flwr.common.version import package_version as _package_version
# ---> 20 from . import client, common, server, simulation
#      22 __all__ = [
#      23     "client",
#      24     "common",
#      25     "server",
#      26     "simulation",
#      27 ]
#      29 __version__ = _package_version
#
# File ~\anaconda3\envs\py310\lib\site-packages\flwr\server\__init__.py:19
#      15 """Flower server."""
#      18 from . import strategy
# ---> 19 from . import workflow as workflow
#      20 from .app import start_server as start_server
#      21 from .client_manager import ClientManager as ClientManager
#
# File ~\anaconda3\envs\py310\lib\site-packages\flwr\server\workflow\__init__.py:18
#       1 # Copyright 2025 Flower Labs GmbH. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Workflows."""
# ---> 18 from .default_workflows import DefaultWorkflow
#      19 from .secure_aggregation import SecAggPlusWorkflow, SecAggWorkflow
#      21 __all__ = [
#      22     "DefaultWorkflow",
#      23     "SecAggPlusWorkflow",
#      24     "SecAggWorkflow",
#      25 ]
#
# File ~\anaconda3\envs\py310\lib\site-packages\flwr\server\workflow\default_workflows.py:38
#      35 from flwr.common.constant import MessageType, MessageTypeLegacy
#      37 from ..client_proxy import ClientProxy
# ---> 38 from ..compat.app_utils import start_update_client_manager_thread
#      39 from ..compat.legacy_context import LegacyContext
#      40 from ..grid import Grid
#
# File ~\anaconda3\envs\py310\lib\site-packages\flwr\server\compat\__init__.py:18
#       1 # Copyright 2025 Flower Labs GmbH. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Flower ServerApp compatibility package."""
# ---> 18 from .app import start_grid as start_grid
#      19 from .legacy_context import LegacyContext as LegacyContext
#      21 __all__ = [
#      22     "LegacyContext",
#      23     "start_grid",
#      24 ]
#
# File ~\anaconda3\envs\py310\lib\site-packages\flwr\server\compat\app.py:28
#      25 from flwr.server.server_config import ServerConfig
#      26 from flwr.server.strategy import Strategy
# ---> 28 from ..grid import Grid
#      29 from .app_utils import start_update_client_manager_thread
#      32 def start_grid(  # pylint: disable=too-many-arguments, too-many-locals
#      33     *,
#      34     grid: Grid,
#    (...)
#      38     client_manager: Optional[ClientManager] = None,
#      39 ) -> History:
#
# File ~\anaconda3\envs\py310\lib\site-packages\flwr\server\grid\__init__.py:20
#      18 from .grid import Driver, Grid
#      19 from .grpc_grid import GrpcGrid
# ---> 20 from .inmemory_grid import InMemoryGrid
#      22 __all__ = [
#      23     "Driver",
#      24     "Grid",
#      25     "GrpcGrid",
#      26     "InMemoryGrid",
#      27 ]
#
# File ~\anaconda3\envs\py310\lib\site-packages\flwr\server\grid\inmemory_grid.py:28
#      26 from flwr.common.typing import Run
#      27 from flwr.proto.node_pb2 import Node  # pylint: disable=E0611
# ---> 28 from flwr.server.superlink.linkstate import LinkStateFactory
#      30 from .grid import Grid
#      33 class InMemoryGrid(Grid):
#
# File ~\anaconda3\envs\py310\lib\site-packages\flwr\server\superlink\linkstate\__init__.py:18
#       1 # Copyright 2025 Flower Labs GmbH. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Flower LinkState."""
# ---> 18 from .in_memory_linkstate import InMemoryLinkState as InMemoryLinkState
#      19 from .linkstate import LinkState as LinkState
#      20 from .linkstate_factory import LinkStateFactory as LinkStateFactory
#
# File ~\anaconda3\envs\py310\lib\site-packages\flwr\server\superlink\linkstate\in_memory_linkstate.py:38
#      36 from flwr.common.typing import Run, RunStatus, UserConfig
#      37 from flwr.server.superlink.linkstate.linkstate import LinkState
# ---> 38 from flwr.server.utils import validate_message
#      40 from .utils import (
#      41     check_node_availability_for_in_message,
#      42     generate_rand_int_from_bytes,
#    (...)
#      46     verify_message_ids,
#      47 )
#      50 @dataclass
#      51 class RunRecord:  # pylint: disable=R0902
#
# File ~\anaconda3\envs\py310\lib\site-packages\flwr\server\utils\__init__.py:18
#       1 # Copyright 2025 Flower Labs GmbH. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Server-side utilities."""
# ---> 18 from .tensorboard import tensorboard as tensorboard
#      19 from .validator import validate_message as validate_message
#      21 __all__ = [
#      22     "tensorboard",
#      23     "validate_message",
#      24 ]
#
# File ~\anaconda3\envs\py310\lib\site-packages\flwr\server\utils\tensorboard.py:29
#      26 from flwr.server.strategy import Strategy
#      28 try:
# ---> 29     import tensorflow as TF
#      30 except ModuleNotFoundError:
#      31     TF = None
#
# File ~\anaconda3\envs\py310\lib\site-packages\tensorflow\__init__.py:37
#      34 import sys as _sys
#      35 import typing as _typing
# ---> 37 from tensorflow.python.tools import module_util as _module_util
#      38 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      40 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# File ~\anaconda3\envs\py310\lib\site-packages\tensorflow\python\__init__.py:37
#      29 # We aim to keep this file minimal and ideally remove completely.
#      30 # If you are adding a new file with @tf_export decorators,
#      31 # import it in modules_with_exports.py instead.
#      32
#      33 # go/tf-wildcard-import
#      34 # pylint: disable=wildcard-import,g-bad-import-order,g-import-not-at-top
#      36 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow
# ---> 37 from tensorflow.python.eager import context
#      39 # pylint: enable=wildcard-import
#      40
#      41 # Bring in subpackages.
#      42 from tensorflow.python import data
#
# File ~\anaconda3\envs\py310\lib\site-packages\tensorflow\python\eager\context.py:29
#      26 import numpy as np
#      27 import six
# ---> 29 from tensorflow.core.framework import function_pb2
#      30 from tensorflow.core.protobuf import config_pb2
#      31 from tensorflow.core.protobuf import coordination_config_pb2
#
# File ~\anaconda3\envs\py310\lib\site-packages\tensorflow\core\framework\function_pb2.py:16
#      11 # @@protoc_insertion_point(imports)
#      13 _sym_db = _symbol_database.Default()
# ---> 16 from tensorflow.core.framework import attr_value_pb2 as tensorflow_dot_core_dot_framework_dot_attr__value__pb2
#      17 from tensorflow.core.framework import node_def_pb2 as tensorflow_dot_core_dot_framework_dot_node__def__pb2
#      18 from tensorflow.core.framework import op_def_pb2 as tensorflow_dot_core_dot_framework_dot_op__def__pb2
#
# File ~\anaconda3\envs\py310\lib\site-packages\tensorflow\core\framework\attr_value_pb2.py:16
#      11 # @@protoc_insertion_point(imports)
#      13 _sym_db = _symbol_database.Default()
# ---> 16 from tensorflow.core.framework import tensor_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__pb2
#      17 from tensorflow.core.framework import tensor_shape_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2
#      18 from tensorflow.core.framework import types_pb2 as tensorflow_dot_core_dot_framework_dot_types__pb2
#
# File ~\anaconda3\envs\py310\lib\site-packages\tensorflow\core\framework\tensor_pb2.py:16
#      11 # @@protoc_insertion_point(imports)
#      13 _sym_db = _symbol_database.Default()
# ---> 16 from tensorflow.core.framework import resource_handle_pb2 as tensorflow_dot_core_dot_framework_dot_resource__handle__pb2
#      17 from tensorflow.core.framework import tensor_shape_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2
#      18 from tensorflow.core.framework import types_pb2 as tensorflow_dot_core_dot_framework_dot_types__pb2
#
# File ~\anaconda3\envs\py310\lib\site-packages\tensorflow\core\framework\resource_handle_pb2.py:16
#      11 # @@protoc_insertion_point(imports)
#      13 _sym_db = _symbol_database.Default()
# ---> 16 from tensorflow.core.framework import tensor_shape_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2
#      17 from tensorflow.core.framework import types_pb2 as tensorflow_dot_core_dot_framework_dot_types__pb2
#      20 DESCRIPTOR = _descriptor.FileDescriptor(
#      21   name='tensorflow/core/framework/resource_handle.proto',
#      22   package='tensorflow',
#    (...)
#      26   ,
#      27   dependencies=[tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2.DESCRIPTOR,tensorflow_dot_core_dot_framework_dot_types__pb2.DESCRIPTOR,])
#
# File ~\anaconda3\envs\py310\lib\site-packages\tensorflow\core\framework\tensor_shape_pb2.py:36
#      13 _sym_db = _symbol_database.Default()
#      18 DESCRIPTOR = _descriptor.FileDescriptor(
#      19   name='tensorflow/core/framework/tensor_shape.proto',
#      20   package='tensorflow',
#    (...)
#      23   serialized_pb=_b('\n,tensorflow/core/framework/tensor_shape.proto\x12\ntensorflow\"z\n\x10TensorShapeProto\x12-\n\x03\x64im\x18\x02 \x03(\x0b\x32 .tensorflow.TensorShapeProto.Dim\x12\x14\n\x0cunknown_rank\x18\x03 \x01(\x08\x1a!\n\x03\x44im\x12\x0c\n\x04size\x18\x01 \x01(\x03\x12\x0c\n\x04name\x18\x02 \x01(\tB\x87\x01\n\x18org.tensorflow.frameworkB\x11TensorShapeProtosP\x01ZSgithub.com/tensorflow/tensorflow/tensorflow/go/core/framework/tensor_shape_go_proto\xf8\x01\x01\x62\x06proto3')
#      24 )
#      29 _TENSORSHAPEPROTO_DIM = _descriptor.Descriptor(
#      30   name='Dim',
#      31   full_name='tensorflow.TensorShapeProto.Dim',
#      32   filename=None,
#      33   file=DESCRIPTOR,
#      34   containing_type=None,
#      35   fields=[
# ---> 36     _descriptor.FieldDescriptor(
#      37       name='size', full_name='tensorflow.TensorShapeProto.Dim.size', index=0,
#      38       number=1, type=3, cpp_type=2, label=1,
#      39       has_default_value=False, default_value=0,
#      40       message_type=None, enum_type=None, containing_type=None,
#      41       is_extension=False, extension_scope=None,
#      42       serialized_options=None, file=DESCRIPTOR),
#      43     _descriptor.FieldDescriptor(
#      44       name='name', full_name='tensorflow.TensorShapeProto.Dim.name', index=1,
#      45       number=2, type=9, cpp_type=9, label=1,
#      46       has_default_value=False, default_value=_b("").decode('utf-8'),
#      47       message_type=None, enum_type=None, containing_type=None,
#      48       is_extension=False, extension_scope=None,
#      49       serialized_options=None, file=DESCRIPTOR),
#      50   ],
#      51   extensions=[
#      52   ],
#      53   nested_types=[],
#      54   enum_types=[
#      55   ],
#      56   serialized_options=None,
#      57   is_extendable=False,
#      58   syntax='proto3',
#      59   extension_ranges=[],
#      60   oneofs=[
#      61   ],
#      62   serialized_start=149,
#      63   serialized_end=182,
#      64 )
#      66 _TENSORSHAPEPROTO = _descriptor.Descriptor(
#      67   name='TensorShapeProto',
#      68   full_name='tensorflow.TensorShapeProto',
#    (...)
#     100   serialized_end=182,
#     101 )
#     103 _TENSORSHAPEPROTO_DIM.containing_type = _TENSORSHAPEPROTO
#
# File ~\anaconda3\envs\py310\lib\site-packages\google\protobuf\descriptor.py:553, in FieldDescriptor.__new__(cls, name, full_name, index, number, type, cpp_type, label, default_value, message_type, enum_type, containing_type, is_extension, extension_scope, options, serialized_options, has_default_value, containing_oneof, json_name, file, create_key)
#     547 def __new__(cls, name, full_name, index, number, type, cpp_type, label,
#     548             default_value, message_type, enum_type, containing_type,
#     549             is_extension, extension_scope, options=None,
#     550             serialized_options=None,
#     551             has_default_value=True, containing_oneof=None, json_name=None,
#     552             file=None, create_key=None):  # pylint: disable=redefined-builtin
# --> 553   _message.Message._CheckCalledFromGeneratedFile()
#     554   if is_extension:
#     555     return _message.default_pool.FindExtensionByName(full_name)
#
# TypeError: Descriptors cannot be created directly.
# If this call came from a _pb2.py file, your generated code is out of date and must be regenerated with protoc >= 3.19.0.
# If you cannot immediately regenerate your protos, some other possible workarounds are:
#  1. Downgrade the protobuf package to 3.20.x or lower.
#  2. Set PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python (but this will use pure-Python parsing and will be much slower).
#
# More information: https://developers.google.com/protocol-buffers/docs/news/2022-05-06#python-updates

# %%
# Out:
# -------------------------------------------------
# ModuleNotFoundErrorTraceback (most recent call last)
# Cell In[24], line 1
# ----> 1 import flwr
#       2 print(flwr.__version__)
#
# ModuleNotFoundError: No module named 'flwr'

# %%
import flwr as fl

from model import create_model

def fit_config(rnd: int):
    return {"batch_size": 32, "local_epochs": 1}

def evaluate_config(rnd: int):
    return {"val_steps": 5}

# Define aggregation strategy
strategy = fl.server.strategy.FedAvg(
    fraction_fit=1.0,
    fraction_eval=1.0,
    min_fit_clients=2,
    min_eval_clients=2,
    min_available_clients=2,
    on_fit_config_fn=fit_config,
    on_evaluate_config_fn=evaluate_config,
)
# Out:
# -------------------------------------------------
# TypeError       Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 import flwr as fl
#       3 from model import create_model
#       5 def fit_config(rnd: int):
#
# File ~\anaconda3\envs\py310\lib\site-packages\flwr\__init__.py:20
#      15 """Flower main package."""
#      18 from flwr.common.version import package_version as _package_version
# ---> 20 from . import client, common, server, simulation
#      22 __all__ = [
#      23     "client",
#      24     "common",
#      25     "server",
#      26     "simulation",
#      27 ]
#      29 __version__ = _package_version
#
# File ~\anaconda3\envs\py310\lib\site-packages\flwr\server\__init__.py:19
#      15 """Flower server."""
#      18 from . import strategy
# ---> 19 from . import workflow as workflow
#      20 from .app import start_server as start_server
#      21 from .client_manager import ClientManager as ClientManager
#
# File ~\anaconda3\envs\py310\lib\site-packages\flwr\server\workflow\__init__.py:18
#       1 # Copyright 2025 Flower Labs GmbH. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Workflows."""
# ---> 18 from .default_workflows import DefaultWorkflow
#      19 from .secure_aggregation import SecAggPlusWorkflow, SecAggWorkflow
#      21 __all__ = [
#      22     "DefaultWorkflow",
#      23     "SecAggPlusWorkflow",
#      24     "SecAggWorkflow",
#      25 ]
#
# File ~\anaconda3\envs\py310\lib\site-packages\flwr\server\workflow\default_workflows.py:38
#      35 from flwr.common.constant import MessageType, MessageTypeLegacy
#      37 from ..client_proxy import ClientProxy
# ---> 38 from ..compat.app_utils import start_update_client_manager_thread
#      39 from ..compat.legacy_context import LegacyContext
#      40 from ..grid import Grid
#
# File ~\anaconda3\envs\py310\lib\site-packages\flwr\server\compat\__init__.py:18
#       1 # Copyright 2025 Flower Labs GmbH. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Flower ServerApp compatibility package."""
# ---> 18 from .app import start_grid as start_grid
#      19 from .legacy_context import LegacyContext as LegacyContext
#      21 __all__ = [
#      22     "LegacyContext",
#      23     "start_grid",
#      24 ]
#
# File ~\anaconda3\envs\py310\lib\site-packages\flwr\server\compat\app.py:28
#      25 from flwr.server.server_config import ServerConfig
#      26 from flwr.server.strategy import Strategy
# ---> 28 from ..grid import Grid
#      29 from .app_utils import start_update_client_manager_thread
#      32 def start_grid(  # pylint: disable=too-many-arguments, too-many-locals
#      33     *,
#      34     grid: Grid,
#    (...)
#      38     client_manager: Optional[ClientManager] = None,
#      39 ) -> History:
#
# File ~\anaconda3\envs\py310\lib\site-packages\flwr\server\grid\__init__.py:20
#      18 from .grid import Driver, Grid
#      19 from .grpc_grid import GrpcGrid
# ---> 20 from .inmemory_grid import InMemoryGrid
#      22 __all__ = [
#      23     "Driver",
#      24     "Grid",
#      25     "GrpcGrid",
#      26     "InMemoryGrid",
#      27 ]
#
# File ~\anaconda3\envs\py310\lib\site-packages\flwr\server\grid\inmemory_grid.py:28
#      26 from flwr.common.typing import Run
#      27 from flwr.proto.node_pb2 import Node  # pylint: disable=E0611
# ---> 28 from flwr.server.superlink.linkstate import LinkStateFactory
#      30 from .grid import Grid
#      33 class InMemoryGrid(Grid):
#
# File ~\anaconda3\envs\py310\lib\site-packages\flwr\server\superlink\linkstate\__init__.py:18
#       1 # Copyright 2025 Flower Labs GmbH. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Flower LinkState."""
# ---> 18 from .in_memory_linkstate import InMemoryLinkState as InMemoryLinkState
#      19 from .linkstate import LinkState as LinkState
#      20 from .linkstate_factory import LinkStateFactory as LinkStateFactory
#
# File ~\anaconda3\envs\py310\lib\site-packages\flwr\server\superlink\linkstate\in_memory_linkstate.py:38
#      36 from flwr.common.typing import Run, RunStatus, UserConfig
#      37 from flwr.server.superlink.linkstate.linkstate import LinkState
# ---> 38 from flwr.server.utils import validate_message
#      40 from .utils import (
#      41     check_node_availability_for_in_message,
#      42     generate_rand_int_from_bytes,
#    (...)
#      46     verify_message_ids,
#      47 )
#      50 @dataclass
#      51 class RunRecord:  # pylint: disable=R0902
#
# File ~\anaconda3\envs\py310\lib\site-packages\flwr\server\utils\__init__.py:18
#       1 # Copyright 2025 Flower Labs GmbH. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Server-side utilities."""
# ---> 18 from .tensorboard import tensorboard as tensorboard
#      19 from .validator import validate_message as validate_message
#      21 __all__ = [
#      22     "tensorboard",
#      23     "validate_message",
#      24 ]
#
# File ~\anaconda3\envs\py310\lib\site-packages\flwr\server\utils\tensorboard.py:29
#      26 from flwr.server.strategy import Strategy
#      28 try:
# ---> 29     import tensorflow as TF
#      30 except ModuleNotFoundError:
#      31     TF = None
#
# File ~\anaconda3\envs\py310\lib\site-packages\tensorflow\__init__.py:37
#      34 import sys as _sys
#      35 import typing as _typing
# ---> 37 from tensorflow.python.tools import module_util as _module_util
#      38 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      40 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# File ~\anaconda3\envs\py310\lib\site-packages\tensorflow\python\__init__.py:37
#      29 # We aim to keep this file minimal and ideally remove completely.
#      30 # If you are adding a new file with @tf_export decorators,
#      31 # import it in modules_with_exports.py instead.
#      32
#      33 # go/tf-wildcard-import
#      34 # pylint: disable=wildcard-import,g-bad-import-order,g-import-not-at-top
#      36 from tensorflow.python import pywrap_tensorflow as _pywrap_tensorflow
# ---> 37 from tensorflow.python.eager import context
#      39 # pylint: enable=wildcard-import
#      40
#      41 # Bring in subpackages.
#      42 from tensorflow.python import data
#
# File ~\anaconda3\envs\py310\lib\site-packages\tensorflow\python\eager\context.py:29
#      26 import numpy as np
#      27 import six
# ---> 29 from tensorflow.core.framework import function_pb2
#      30 from tensorflow.core.protobuf import config_pb2
#      31 from tensorflow.core.protobuf import coordination_config_pb2
#
# File ~\anaconda3\envs\py310\lib\site-packages\tensorflow\core\framework\function_pb2.py:16
#      11 # @@protoc_insertion_point(imports)
#      13 _sym_db = _symbol_database.Default()
# ---> 16 from tensorflow.core.framework import attr_value_pb2 as tensorflow_dot_core_dot_framework_dot_attr__value__pb2
#      17 from tensorflow.core.framework import node_def_pb2 as tensorflow_dot_core_dot_framework_dot_node__def__pb2
#      18 from tensorflow.core.framework import op_def_pb2 as tensorflow_dot_core_dot_framework_dot_op__def__pb2
#
# File ~\anaconda3\envs\py310\lib\site-packages\tensorflow\core\framework\attr_value_pb2.py:16
#      11 # @@protoc_insertion_point(imports)
#      13 _sym_db = _symbol_database.Default()
# ---> 16 from tensorflow.core.framework import tensor_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__pb2
#      17 from tensorflow.core.framework import tensor_shape_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2
#      18 from tensorflow.core.framework import types_pb2 as tensorflow_dot_core_dot_framework_dot_types__pb2
#
# File ~\anaconda3\envs\py310\lib\site-packages\tensorflow\core\framework\tensor_pb2.py:16
#      11 # @@protoc_insertion_point(imports)
#      13 _sym_db = _symbol_database.Default()
# ---> 16 from tensorflow.core.framework import resource_handle_pb2 as tensorflow_dot_core_dot_framework_dot_resource__handle__pb2
#      17 from tensorflow.core.framework import tensor_shape_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2
#      18 from tensorflow.core.framework import types_pb2 as tensorflow_dot_core_dot_framework_dot_types__pb2
#
# File ~\anaconda3\envs\py310\lib\site-packages\tensorflow\core\framework\resource_handle_pb2.py:16
#      11 # @@protoc_insertion_point(imports)
#      13 _sym_db = _symbol_database.Default()
# ---> 16 from tensorflow.core.framework import tensor_shape_pb2 as tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2
#      17 from tensorflow.core.framework import types_pb2 as tensorflow_dot_core_dot_framework_dot_types__pb2
#      20 DESCRIPTOR = _descriptor.FileDescriptor(
#      21   name='tensorflow/core/framework/resource_handle.proto',
#      22   package='tensorflow',
#    (...)
#      26   ,
#      27   dependencies=[tensorflow_dot_core_dot_framework_dot_tensor__shape__pb2.DESCRIPTOR,tensorflow_dot_core_dot_framework_dot_types__pb2.DESCRIPTOR,])
#
# File ~\anaconda3\envs\py310\lib\site-packages\tensorflow\core\framework\tensor_shape_pb2.py:36
#      13 _sym_db = _symbol_database.Default()
#      18 DESCRIPTOR = _descriptor.FileDescriptor(
#      19   name='tensorflow/core/framework/tensor_shape.proto',
#      20   package='tensorflow',
#    (...)
#      23   serialized_pb=_b('\n,tensorflow/core/framework/tensor_shape.proto\x12\ntensorflow\"z\n\x10TensorShapeProto\x12-\n\x03\x64im\x18\x02 \x03(\x0b\x32 .tensorflow.TensorShapeProto.Dim\x12\x14\n\x0cunknown_rank\x18\x03 \x01(\x08\x1a!\n\x03\x44im\x12\x0c\n\x04size\x18\x01 \x01(\x03\x12\x0c\n\x04name\x18\x02 \x01(\tB\x87\x01\n\x18org.tensorflow.frameworkB\x11TensorShapeProtosP\x01ZSgithub.com/tensorflow/tensorflow/tensorflow/go/core/framework/tensor_shape_go_proto\xf8\x01\x01\x62\x06proto3')
#      24 )
#      29 _TENSORSHAPEPROTO_DIM = _descriptor.Descriptor(
#      30   name='Dim',
#      31   full_name='tensorflow.TensorShapeProto.Dim',
#      32   filename=None,
#      33   file=DESCRIPTOR,
#      34   containing_type=None,
#      35   fields=[
# ---> 36     _descriptor.FieldDescriptor(
#      37       name='size', full_name='tensorflow.TensorShapeProto.Dim.size', index=0,
#      38       number=1, type=3, cpp_type=2, label=1,
#      39       has_default_value=False, default_value=0,
#      40       message_type=None, enum_type=None, containing_type=None,
#      41       is_extension=False, extension_scope=None,
#      42       serialized_options=None, file=DESCRIPTOR),
#      43     _descriptor.FieldDescriptor(
#      44       name='name', full_name='tensorflow.TensorShapeProto.Dim.name', index=1,
#      45       number=2, type=9, cpp_type=9, label=1,
#      46       has_default_value=False, default_value=_b("").decode('utf-8'),
#      47       message_type=None, enum_type=None, containing_type=None,
#      48       is_extension=False, extension_scope=None,
#      49       serialized_options=None, file=DESCRIPTOR),
#      50   ],
#      51   extensions=[
#      52   ],
#      53   nested_types=[],
#      54   enum_types=[
#      55   ],
#      56   serialized_options=None,
#      57   is_extendable=False,
#      58   syntax='proto3',
#      59   extension_ranges=[],
#      60   oneofs=[
#      61   ],
#      62   serialized_start=149,
#      63   serialized_end=182,
#      64 )
#      66 _TENSORSHAPEPROTO = _descriptor.Descriptor(
#      67   name='TensorShapeProto',
#      68   full_name='tensorflow.TensorShapeProto',
#    (...)
#     100   serialized_end=182,
#     101 )
#     103 _TENSORSHAPEPROTO_DIM.containing_type = _TENSORSHAPEPROTO
#
# File ~\anaconda3\envs\py310\lib\site-packages\google\protobuf\descriptor.py:553, in FieldDescriptor.__new__(cls, name, full_name, index, number, type, cpp_type, label, default_value, message_type, enum_type, containing_type, is_extension, extension_scope, options, serialized_options, has_default_value, containing_oneof, json_name, file, create_key)
#     547 def __new__(cls, name, full_name, index, number, type, cpp_type, label,
#     548             default_value, message_type, enum_type, containing_type,
#     549             is_extension, extension_scope, options=None,
#     550             serialized_options=None,
#     551             has_default_value=True, containing_oneof=None, json_name=None,
#     552             file=None, create_key=None):  # pylint: disable=redefined-builtin
# --> 553   _message.Message._CheckCalledFromGeneratedFile()
#     554   if is_extension:
#     555     return _message.default_pool.FindExtensionByName(full_name)
#
# TypeError: Descriptors cannot be created directly.
# If this call came from a _pb2.py file, your generated code is out of date and must be regenerated with protoc >= 3.19.0.
# If you cannot immediately regenerate your protos, some other possible workarounds are:
#  1. Downgrade the protobuf package to 3.20.x or lower.
#  2. Set PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python (but this will use pure-Python parsing and will be much slower).
#
# More information: https://developers.google.com/protocol-buffers/docs/news/2022-05-06#python-updates

# %%
import flwr as fl

if __name__ == "__main__":
    fl.server.start_server(server_address="localhost:8085", 
                           config={"num_rounds": 3},
                           strategy=strategy)
